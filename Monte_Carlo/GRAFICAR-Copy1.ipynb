# %%
import numpy as np
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
potencial = np.loadtxt('pot.dat')
g = np.loadtxt('g.dat')
e = np.loadtxt('e.dat')
confin = np.loadtxt('conf_fin.dat')

# %% [markdown]
# ## Grafica del potencial

# %%
plt.plot(potencial[450:,0], potencial[450:,1])
plt.ylim(-1.9,0.6)
plt.xlim(0.75,2.4)
# Out:
# (0.75, 2.4)

# %% [markdown]
# ## Grafica de energia por particula

# %%
plt.plot(e[0:,0], e[0:,1])

# %% [markdown]
# ## Configuracion final

# %%
fig = pyplot.figure()
ax = Axes3D(fig)          
ax.scatter(confin[0:,0], confin[0:,1], confin[0:,2])
#plt.ylim(-10, 55, 55)
# Out:
# /tmp/ipykernel_488/3460729637.py:2: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
